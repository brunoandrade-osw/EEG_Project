# %%
import mne
import pandas as pd

print("--- Teste do Ambiente Codespaces ---")
print(f"Versão do MNE instalada: {mne.__version__}")
print(f"Versão do Pandas instalada: {pd.__version__}")

# Tenta carregar os metadados de um arquivo .edf
try:
    raw = mne.io.read_raw_edf('TEA_G_26.edf', preload=False)
    print("\nSucesso! Consegui ler os metadados do arquivo 'TEA_G_26.edf'.")
    print(f"O arquivo tem {raw.info['nchan']} canais.")
except Exception as e:
    print(f"\nErro ao tentar ler o arquivo .edf: {e}")

print("\nAmbiente configurado e pronto para uso!")
# Out:
# --- Teste do Ambiente Codespaces ---
# Versão do MNE instalada: 1.10.1
# Versão do Pandas instalada: 2.3.2
# Extracting EDF parameters from /workspaces/EEG_Project/TEA_G_26.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# Sucesso! Consegui ler os metadados do arquivo 'TEA_G_26.edf'.
# O arquivo tem 43 canais.
#
# Ambiente configurado e pronto para uso!
# /tmp/ipykernel_4901/25402923.py:10: RuntimeWarning: Scaling factor is not defined in following channels:
# POL SpO2, POL EtCO2, POL Pulse, POL CO2Wave
#   raw = mne.io.read_raw_edf('TEA_G_26.edf', preload=False)
# /tmp/ipykernel_4901/25402923.py:10: RuntimeWarning: Physical range is not defined in following channels:
# POL SpO2, POL EtCO2, POL Pulse, POL CO2Wave
#   raw = mne.io.read_raw_edf('TEA_G_26.edf', preload=False)

# %%
mkdir -p data/raw data/processed notebooks scripts results

# %%
# !ls
# Out:
#  TEA_G_26.edf   TEA_M_22.edf		        control_50.edf
#  TEA_G_28.edf   TEA_M_22_1.edf		        control_51.edf
#  TEA_G_30.edf   control_12.edf		        control_54.edf
#  TEA_G_40.edf   control_13.edf		        control_55.edf
#  TEA_L_16.edf  'control_14-sem marcacoes.edf'   control_56.edf
#  TEA_L_17.edf   control_35.edf		        control_57.edf
#  TEA_L_24.edf   control_36.edf		        control_58.edf
#  TEA_L_25.edf   control_37.edf		        control_59.edf
#  TEA_L_27.edf   control_38.edf		        control_60.edf
#  TEA_L_29.edf   control_39.edf		        control_61.edf
#  TEA_L_32.edf   control_41.edf		        data
#  TEA_L_46.edf   control_42.edf		        notebooks
#  TEA_M_15.edf   control_43.edf		        requirements.txt
#  TEA_M_18.edf   control_44.edf		        results
#  TEA_M_19.edf   control_47.edf		        scripts
#  TEA_M_20.edf   control_48.edf
#  TEA_M_21.edf   control_49.edf

# %%
pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 43.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 42.5 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 46.4 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 47.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 44.7 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 47.8 MB/s eta 0:00:00:00:01
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.7.0
#     Uninstalling scikit-learn-1.7.0:
#       Successfully uninstalled scikit-learn-1.7.0 0/6 [scikit-learn]
#   Attempting uninstall: pandas━━━━━━━━━━━━━━━━━━ 0/6 [scikit-learn]
#     Found existing installation: pandas 2.3.2 0/6 [scikit-learn]
#     Uninstalling pandas-2.3.2:90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/6 [pandas]
# ...

# %%
# !python -m pip install --upgrade pip
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 35.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 25.1.1
#     Uninstalling pip-25.1.1:
#       Successfully uninstalled pip-25.1.1
#   WARNING: The scripts pip, pip3 and pip3.12 are installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...

# %%
mv *.edf data/raw/
